# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint
import os
path='C:\\Users\\aemra\\Documents\\GitHub\\Wrangle-OpenStreetMap-Data'
os.chdir(path)
OSMFILE = "houston_texas.osm"


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons",'Freeway','Road','Way']



def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def update_name(name, mapping):
    for v in mapping:
        #print v
        if re.search(v,name):
            name=name.replace(v,mapping[v])
            print (name )         
            return name
        else:
            pass
mapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Rd." : "Road",
           'Ave.': 'Avenue',
           'Blvd' : 'Boulevard',
           'Blvd.':'Boulevard',
           'Dr': 'Drive',
           'Frwy':'Freeway',
           'Pkwy': 'Parkway',
           'Rd':'Road',
           'Rd.':'Road',
           'Stree':'Street',
           'blvd':'Boulevard',
           'street':'Street'
            }

def get_element(osm_file):
    """Yield element 
    """
    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end':
            yield elem
            root.clear()
   
def audit(osmfile):
    street_types = defaultdict(set)
    for elem in get_element(osmfile):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    return street_types




def test():
    st_types = audit(OSMFILE)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.items():
        for name in ways:
            better_name = update_name(name, mapping)
            print (name, "=>", better_name)
    
if __name__ == '__main__':
    test()
# Out:
# {'1/2': {'Avenue M 1/2', 'Avenue R 1/2'},
#  '10': {'I 10'},
#  '101': {'FM 78, Suite 101'},
#  '110': {'Memorial Drive, Ste 110'},
#  '1142': {'Lake Woodlands Drive #1142'},
#  '125': {'798 Sorella Court Suite 125'},
#  '146': {'TX 146', 'Texas 146'},
#  '1464': {'FM 1464'},
#  '1488': {'Farm-to-Market Road 1488', 'FM 1488'},
#  '150': {'Garth Road Suite 150'},
#  '160': {'Nelson Way #160'},
#  '1640': {'FM 1640'},
#  '1663': {'FM 1663'},
#  '1764': {'Farm-to-Market Road 1764', 'FM 1764'},
#  '1774': {'Farm-to-Market Road 1774'},
#  '18': {'800 W NASA Parkway #18'},
#  '180': {'Katy Freeway #180'},
#  '185': {'I-45 South, Suite 185'},
#  '1960': {'Fm 1960', 'FM 1960'},
#  '200': {'College Park Drive Ste 200'},
#  '2100': {'FM 2100'},
#  '216': {'Briarhills Pkwy #216'},
#  '240': {'Bissonnet St #240'},
#  '242': {'SH 242'},
#  '249': {'TX 249'},
#  '270': {'FM 270'},
#  '290': {'Highway 290', 'Windfern Rd #290', 'US 290'},
#  '2920': {'FM 2920', 'Fm 2920'},
#  '300': {'Town & Country Blvd #300'},
#  '332': {'West Highway 332', 'TX 332'},
#  '359': {'FM 359', 'Fm 359'},
#  '36': {'TX 36', 'Highway 36'},
#  '362': {'FM 362'},
#  '45': {'I 45'},
#  '5': {'Farm to Market Rd 1488 #5'},
#  '502': {'Northwest Freeway #502'},
#  '518': {'FM 518', 'West FM 518'},
#  '529': {'FM 529', 'Farm to Market Road 529'},
#  '59': {'United States Highway 59', 'Southwest Freeway 59', 'US 59'},
#  '6': {'Highway 6',
#        'S Highway 6',
#        'State Hwy 6',
#        'TX 6',
#        'Texas Highway 6',
#        'West Highway 6'},
#  '646': {'FM 646'},
#  '6475': {'County Rd 6475'},
#  '65': {'County Rd 65'},
#  '650': {'W Broadway, Suite 650'},
#  '704': {'Memorial City Way #704'},
#  '77027': {'77027'},
#  '77096': {'Meyerland Plaza, Houston, TX 77096'},
#  '800': {'Katy Fwy #800'},
#  '87': {'Highway 87'},
#  '90': {'US 90', 'Highway 90'},
#  '90A': {'Highway 90A'},
#  '90a': {'Hwy 90a'},
#  '925': {'Katy Freeway Suite 925'},
#  '94': {'County Road 94'},
#  '940': {'St Joseph Pkwy #940'},
#  '9k': {'I-45 #9k'},
#  'A': {'Avenue A', 'Dickinson Avenue Suite A'},
#  'AVE': {'Harris AVE'},
#  'AVENUE': {'SSPRANGLETOP AVENUE'},
#  'Americas': {'Avenida de Las Americas'},
#  'Ave': {'7828 N 19th Ave',
#          'Houston Ave',
#          'Lake Robbins Ave',
#          'N Houston Ave',
#          'Richmond Ave',
#          'S. Rice Ave',
#          'W Bellfort Ave',
#          'W Texas Ave',
#          'Washington Ave'},
#  'Ave.': {'Bertner Ave.'},
#  'B': {'W Holcombe Blvd #B', 'Fry Road Suite B', 'Richmond Ave, Ste B'},
#  'Bailey': {'Bailey'},
#  'Beechnut': {'Beechnut'},
#  'Blossom': {'Blossom'},
#  'Blvd': {'Highland Blvd',
#           'John Freeman Blvd',
#           'Pasadena Blvd',
#           'Post Oak Blvd',
#           'Seawall Blvd',
#           'Sweetwater Blvd',
#           'University Blvd'},
#  'Blvd.': {'Central City Blvd.', 'Post Oak Blvd.', 'Bellaire Blvd.'},
#  'Broadway': {'Broadway'},
#  'Bypass': {'Alvin Bypass', 'US 290 Bypass', 'E Fm 1960 Bypass'},
#  'Caroline': {'Caroline'},
#  'Circle': {'Bonnard Circle',
#             'Capella Circle',
#             'Lansing Circle',
#             'South Hidden View Circle',
#             'West Town Center Circle'},
#  'Crossing': {'Woodland Field Crossing', 'Brazos Town Crossing'},
#  'Crosstimbers': {'West Crosstimbers'},
#  'Cypress': {'Baker Cypress'},
#  'DRIVE': {'STONEY CLOUD DRIVE'},
#  'Dallas': {'W. Dallas'},
#  'Dr': {'1111 Upland Dr',
#         'Business Center Dr',
#         'E Knox Dr',
#         'Kensington Dr',
#         'New Hampton Dr',
#         'Office Park Dr',
#         'Park Row Dr',
#         'Portway Dr',
#         'Post Oak Place Dr',
#         'S Wilcrest Dr',
#         'Six Pines Dr',
#         'Waugh Dr'},
#  'Driscoll': {'Driscoll'},
#  'Durham': {'Durham'},
#  'E': {'FM 1960 E', 'Avenue E'},
#  'East': {'North Sam Houston Parkway East', 'South Loop East', 'FM 1960 East'},
#  'Es': {'Es'},
#  'F': {'Winbern Street, Ste. F', 'San Felipe Road, suite F', 'Avenue F'},
#  'F463': {'Memorial Drive Suite F463'},
#  'Felipe': {'San Felipe'},
#  'Frwy': {'East Frwy'},
#  'Fuzzel': {'Riley Fuzzel'},
#  'Fwy': {'Gulf Fwy', 'Northwest Fwy', 'Katy Fwy', 'Southwest Fwy'},
#  'Graustark': {'Graustark'},
#  'Gulfcrest': {'Gulfcrest'},
#  'HIGHWAY': {'PALMER HIGHWAY'},
#  'Hidalgo': {'Hidalgo'},
#  'Highway': {'Palmer Highway', 'Spencer Highway'},
#  'Hillcroft': {'Hillcroft'},
#  'Houston': {'W Lake Houston Pkwy, Houston'},
#  'I-45': {'I-45'},
#  'Isle': {'Morgan Isle'},
#  'Kempwood': {'Kempwood'},
#  'Knolls': {'Everett Knolls'},
#  'L': {'Avenue L'},
#  'Lake': {'Woodcreek Bend Lake'},
#  'Larchmont': {'Larchmont'},
#  'Ln': {'Iris Bay Ln'},
#  'Loop': {'Taub Loop'},
#  'MacGregor': {'South MacGregor'},
#  'Mall': {'Baybrook Mall', 'Meyerland Plaza Mall'},
#  'Maroneal': {'Maroneal'},
#  'Mews': {'Chesham Mews'},
#  'Montrose': {'Montrose'},
#  'N': {'East Sam Houston Pkwy N',
#        'Kingwood Drive #N',
#        'W Sam Houston Pky N',
#        'W Sam Houston Pwky N'},
#  'N,': {'East Sam Houston Pkwy N,'},
#  'North': {'East Sam Houston Parkway North',
#            'Grand Parkway North',
#            'Highway 59 North',
#            'Highway 6 North',
#            'Hwy 6 North',
#            'Interstate 45 North',
#            'Kings Manor Drive North',
#            'Raider Circle North',
#            'United States Highway 59 North',
#            'West Sam Houston Parkway North',
#            'Willow Place Drive North'},
#  'O': {'Avenue O'},
#  'Oaks': {'West Spreading Oaks'},
#  'Park': {'Pin Oak Park', 'NRG Park', 'Deer Park'},
#  'Pkwy': {'Shadow Creek Pkwy',
#           'Tomball Pkwy',
#           'West Lake Houston Pkwy',
#           'Will Clayton Pkwy'},
#  'Plaza': {'E Greenway Plaza', 'One Baylor Plaza', 'Baylor Plaza'},
#  'Plaze': {'One Baylor Plaze'},
#  'Q': {'Avenue Q'},
#  'Rd': {'Cypress North Houston Rd',
#         'E Atascocita Rd',
#         'E FM 528 Rd',
#         'Kuykendahl Rd',
#         'Old Katy Rd',
#         'Powerline Rd',
#         'Rogerdale Rd',
#         'Spring Cypress Rd',
#         'Stuebner Airline Rd',
#         'Westheimer Rd'},
#  'Rd.': {'W. Greens Rd.', '1795 N Fry Rd.'},
#  'Real': {'El Camino Real'},
#  'Richmond': {'Richmond'},
#  'Ridge': {'Creek Ridge'},
#  'Riverway': {'Riverway'},
#  'Road)': {'FM 1960 East (Humble-Huffman Road)'},
#  'Rock': {'Chimney Rock'},
#  'Row': {'Park Row'},
#  'S': {'W Grand Pkwy S', 'I-45 S', 'Avenue S'},
#  'ST': {'MONTGOMERY ST'},
#  'South': {'Airline Road South',
#            'E. Sam Houston Parkway South',
#            'West Grand Parkway South',
#            'West Loop South',
#            'West Sam Houston Parkway South',
#            'West Sam Houston Pkwy South'},
#  'Speedway': {'Buffalo Speedway'},
#  'St': {' W Clayton St',
#         'Beverlyhill St',
#         'Canal St',
#         'Dunlavy St',
#         'McCarty St',
#         'Milby St',
#         'Milwee St',
#         'N Delmar St',
#         'S Persimmon St',
#         'San Felipe St',
#         'Tuam St',
#         'W Gray St'},
#  'St.': {'East 13th St.', 'Dallas St.'},
#  'Stree': {'7th Stree'},
#  'T': {'Avenue T'},
#  'T2008': {'Southwest Freeway #T2008'},
#  'TX-332': {'TX-332'},
#  'TX-6': {'TX-6'},
#  'Terrace': {'Skyview Terrace'},
#  'Texas': {'BIRNHAM WOODS DRIVE SPRING, Texas'},
#  'Valley': {'Pine Valley'},
#  'Walk': {'City Walk'},
#  'Welford': {'Welford'},
#  'West': {'1960 West',
#           'FM 1960 West',
#           'Farm to Market 1960 Road West',
#           'Hwy 290 West',
#           'North Loop West',
#           'South Loop West',
#           'South Sam Houston Parkway West'},
#  'Westheimer': {'Westheimer'},
#  'Westhimer': {'Westhimer'},
#  'blvd': {'Highland blvd'},
#  'street': {'Washington street', '32nd street'}}
# El Camino Real => None
# FM 518 => None
# West FM 518 => None
# Central City Boulevard
# Central City Blvd. => Central City Boulevard
# Post Oak Boulevard
# Post Oak Blvd. => Post Oak Boulevard
# Bellaire Boulevard
# Bellaire Blvd. => Bellaire Boulevard
# S. Rice Avenue
# S. Rice Ave => S. Rice Avenue
# Houston Avenue
# Houston Ave => Houston Avenue
# Richmond Avenue
# Richmond Ave => Richmond Avenue
# W Texas Avenue
# W Texas Ave => W Texas Avenue
# Lake Robbins Avenue
# Lake Robbins Ave => Lake Robbins Avenue
# N Houston Avenue
# N Houston Ave => N Houston Avenue
# W Bellfort Avenue
# W Bellfort Ave => W Bellfort Avenue
# 7828 N 19th Avenue
# 7828 N 19th Ave => 7828 N 19th Avenue
# Washington Avenue
# Washington Ave => Washington Avenue
# Fm 1960 => None
# FM 1960 => None
# County Road 94 => None
# West Loop South => None
# West Sam Houston Parkway South
# West Sam Houston Pkwy South => West Sam Houston Parkway South
# E. Sam Houston Parkway South => None
# West Sam Houston Parkway South => None
# West Grand Parkway South => None
# Airline Road South => None
# FM 1960 E => None
# Avenuenue E
# Avenue E => Avenuenue E
# Westheimer => None
# Memorial City Way #704 => None
# Bissonnet Street #240
# Bissonnet St #240 => Bissonnet Street #240
# Welford => None
# E Greenway Plaza => None
# One Baylor Plaza => None
# Baylor Plaza => None
# County Rd 65
# County Rd 65 => County Rd 65
# Hwy 90a => None
# Bonnard Circle => None
# South Hidden View Circle => None
# West Town Center Circle => None
# Capella Circle => None
# Lansing Circle => None
# 7th Streetree
# 7th Stree => 7th Streetree
# Highland Boulevard
# Highland Blvd => Highland Boulevard
# Seawall Boulevard
# Seawall Blvd => Seawall Boulevard
# Post Oak Boulevard
# Post Oak Blvd => Post Oak Boulevard
# Pasadena Boulevard
# Pasadena Blvd => Pasadena Boulevard
# University Boulevard
# University Blvd => University Boulevard
# Sweetwater Boulevard
# Sweetwater Blvd => Sweetwater Boulevard
# John Freeman Boulevard
# John Freeman Blvd => John Freeman Boulevard
# TX-332 => None
# Avenuenue Q
# Avenue Q => Avenuenue Q
# Garth Road Suite 150 => None
# FM 2100 => None
# FM 78, Suite 101 => None
# Pin Oak Park => None
# NRG Park => None
# Deer Park => None
# I-45 => None
# TX 146 => None
# Texas 146 => None
# Farm-to-Market Road 1764 => None
# FM 1764 => None
# Farm-to-Market Road 1488 => None
# FM 1488 => None
# Es => None
# SSPRANGLETOP AVENUE => None
# Beechnut => None
# Park Row => None
# Avenuenue L
# Avenue L => Avenuenue L
# 798 Sorella Court Suite 125 => None
# FM 1960 East (Humble-Huffman Road) => None
# Durham => None
# SH 242 => None
# Baker Cypress => None
# Farm to Market Rd 1488 #5
# Farm to Market Rd 1488 #5 => Farm to Market Rd 1488 #5
# FM 529 => None
# Farm to Market Road 529 => None
# Memorial Driveive Suite F463
# Memorial Drive Suite F463 => Memorial Driveive Suite F463
# Highway 90A => None
# MONTGOMERY ST => None
# Avenuenue A
# Avenue A => Avenuenue A
# Dickinson Avenuenue Suite A
# Dickinson Avenue Suite A => Dickinson Avenuenue Suite A
# 800 W NASA Parkway #18 => None
# Bertner Avenue.
# Bertner Ave. => Bertner Avenue.
# Blossom => None
# College Park Drive Streete 200
# College Park Drive Ste 200 => College Park Drive Streete 200
# FM 359 => None
# Fm 359 => None
# Meyerland Plaza, Houston, TX 77096 => None
# Katy Freeway #180 => None
# Tomball Parkway
# Tomball Pkwy => Tomball Parkway
# Shadow Creek Parkway
# Shadow Creek Pkwy => Shadow Creek Parkway
# West Lake Houston Parkway
# West Lake Houston Pkwy => West Lake Houston Parkway
# Will Clayton Parkway
# Will Clayton Pkwy => Will Clayton Parkway
# East 13th Street.
# East 13th St. => East 13th Street.
# Dallas Street.
# Dallas St. => Dallas Street.
# W Holcombe Blvd #B
# W Holcombe Blvd #B => W Holcombe Blvd #B
# Fry Road Suite B => None
# Richmond Avenue, Ste B
# Richmond Ave, Ste B => Richmond Avenue, Ste B
# Hidalgo => None
# Lake Woodlands Driveive #1142
# Lake Woodlands Drive #1142 => Lake Woodlands Driveive #1142
# Highland Boulevard
# Highland blvd => Highland Boulevard
# Caroline => None
# W Broadway, Suite 650 => None
# Avenuenida de Las Americas
# Avenida de Las Americas => Avenuenida de Las Americas
# I 45 => None
# PALMER HIGHWAY => None
# Avenuenue O
# Avenue O => Avenuenue O
# San Felipe Street
# San Felipe St => San Felipe Street
#  W Clayton Street
#  W Clayton St =>  W Clayton Street
# N Delmar Street
# N Delmar St => N Delmar Street
# Dunlavy Street
# Dunlavy St => Dunlavy Street
# Tuam Street
# Tuam St => Tuam Street
# Milwee Street
# Milwee St => Milwee Street
# W Gray Street
# W Gray St => W Gray Street
# Canal Street
# Canal St => Canal Street
# McCarty Street
# McCarty St => McCarty Street
# Beverlyhill Street
# Beverlyhill St => Beverlyhill Street
# Milby Street
# Milby St => Milby Street
# S Persimmon Street
# S Persimmon St => S Persimmon Street
# TX 249 => None
# STONEY CLOUD DRIVE => None
# Bailey => None
# I-45 South, Suite 185 => None
# Memorial Drive, Streete 110
# Memorial Drive, Ste 110 => Memorial Drive, Streete 110
# North Sam Houston Parkway East => None
# South Loop East => None
# FM 1960 East => None
# Southwest Freeway #T2008 => None
# One Baylor Plaze => None
# Highway 290 => None
# Windfern Rd #290
# Windfern Rd #290 => Windfern Rd #290
# US 290 => None
# Streetuebner Airline Rd
# Stuebner Airline Rd => Streetuebner Airline Rd
# E FM 528 Road
# E FM 528 Rd => E FM 528 Road
# Powerline Road
# Powerline Rd => Powerline Road
# E Atascocita Road
# E Atascocita Rd => E Atascocita Road
# Kuykendahl Road
# Kuykendahl Rd => Kuykendahl Road
# Cypress North Houston Road
# Cypress North Houston Rd => Cypress North Houston Road
# Spring Cypress Road
# Spring Cypress Rd => Spring Cypress Road
# Rogerdale Road
# Rogerdale Rd => Rogerdale Road
# Old Katy Road
# Old Katy Rd => Old Katy Road
# Westheimer Road
# Westheimer Rd => Westheimer Road
# Baybrook Mall => None
# Meyerland Plaza Mall => None
# TX-6 => None
# Post Oak Place Drive
# Post Oak Place Dr => Post Oak Place Drive
# Waugh Drive
# Waugh Dr => Waugh Drive
# Office Park Drive
# Office Park Dr => Office Park Drive
# Portway Drive
# Portway Dr => Portway Drive
# S Wilcrest Drive
# S Wilcrest Dr => S Wilcrest Drive
# New Hampton Drive
# New Hampton Dr => New Hampton Drive
# Business Center Drive
# Business Center Dr => Business Center Drive
# Park Row Drive
# Park Row Dr => Park Row Drive
# E Knox Drive
# E Knox Dr => E Knox Drive
# 1111 Upland Drive
# 1111 Upland Dr => 1111 Upland Drive
# Kensington Drive
# Kensington Dr => Kensington Drive
# Six Pines Drive
# Six Pines Dr => Six Pines Drive
# County Rd 6475
# County Rd 6475 => County Rd 6475
# W. Dallas => None
# City Walk => None
# South MacGregor => None
# Gulfcrest => None
# East Freeway
# East Frwy => East Freeway
# Street Joseph Pkwy #940
# St Joseph Pkwy #940 => Street Joseph Pkwy #940
# Gulf Fwy => None
# Northwest Fwy => None
# Katy Fwy => None
# Southwest Fwy => None
# Kempwood => None
# FM 1640 => None
# Riverway => None
# West Crosstimbers => None
# Driveiscoll
# Driscoll => Driveiscoll
# Pine Valley => None
# FM 1663 => None
# US 90 => None
# Highway 90 => None
# Avenuenue M 1/2
# Avenue M 1/2 => Avenuenue M 1/2
# Avenuenue R 1/2
# Avenue R 1/2 => Avenuenue R 1/2
# Creek Ridge => None
# Katy Freeway Suite 925 => None
# Broadway => None
# Farm to Market 1960 Road West => None
# 1960 West => None
# South Loop West => None
# South Sam Houston Parkway West => None
# FM 1960 West => None
# Hwy 290 West => None
# North Loop West => None
# Texas Highway 6 => None
# Streetate Hwy 6
# State Hwy 6 => Streetate Hwy 6
# West Highway 6 => None
# S Highway 6 => None
# TX 6 => None
# Highway 6 => None
# Graustark => None
# Washington Street
# Washington street => Washington Street
# 32nd Street
# 32nd street => 32nd Street
# Richmond => None
# W Lake Houston Parkway, Houston
# W Lake Houston Pkwy, Houston => W Lake Houston Parkway, Houston
# Woodland Field Crossing => None
# Brazos Town Crossing => None
# Hillcroft => None
# FM 1464 => None
# Katy Fwy #800 => None
# East Sam Houston Parkway N,
# East Sam Houston Pkwy N, => East Sam Houston Parkway N,
# W Grand Parkway S
# W Grand Pkwy S => W Grand Parkway S
# I-45 S => None
# Avenuenue S
# Avenue S => Avenuenue S
# Iris Bay Ln => None
# Chimney Rock => None
# Northwest Freeway #502 => None
# Chesham Mews => None
# FM 362 => None
# West Spreading Oaks => None
# Farm-to-Market Road 1774 => None
# W. Greens Road
# W. Greens Rd. => W. Greens Road
# 1795 N Fry Road
# 1795 N Fry Rd. => 1795 N Fry Road
# Highway 87 => None
# Westhimer => None
# Taub Loop => None
# Harris AVE => None
# I 10 => None
# Palmer Highway => None
# Spencer Highway => None
# Alvin Bypass => None
# US 290 Bypass => None
# E Fm 1960 Bypass => None
# West Highway 332 => None
# TX 332 => None
# FM 270 => None
# Montrose => None
# Nelson Way #160 => None
# United Streetates Highway 59
# United States Highway 59 => United Streetates Highway 59
# Southwest Freeway 59 => None
# US 59 => None
# San Felipe => None
# FM 646 => None
# Skyview Terrace => None
# FM 2920 => None
# Fm 2920 => None
# Buffalo Speedway => None
# BIRNHAM WOODS DRIVE SPRING, Texas => None
# Winbern Streetreet, Streete. F
# Winbern Street, Ste. F => Winbern Streetreet, Streete. F
# San Felipe Road, suite F => None
# Avenuenue F
# Avenue F => Avenuenue F
# Maroneal => None
# Woodcreek Bend Lake => None
# Briarhills Parkway #216
# Briarhills Pkwy #216 => Briarhills Parkway #216
# 77027 => None
# W Sam Houston Pky N => None
# W Sam Houston Pwky N => None
# East Sam Houston Parkway N
# East Sam Houston Pkwy N => East Sam Houston Parkway N
# Kingwood Driveive #N
# Kingwood Drive #N => Kingwood Driveive #N
# Avenuenue T
# Avenue T => Avenuenue T
# Raider Circle North => None
# Kings Manor Driveive North
# Kings Manor Drive North => Kings Manor Driveive North
# United Streetates Highway 59 North
# United States Highway 59 North => United Streetates Highway 59 North
# Grand Parkway North => None
# Hwy 6 North => None
# West Sam Houston Parkway North => None
# Willow Place Driveive North
# Willow Place Drive North => Willow Place Driveive North
# Highway 6 North => None
# Highway 59 North => None
# Interstate 45 North => None
# East Sam Houston Parkway North => None
# Morgan Isle => None
# I-45 #9k => None
# Town & Country Blvd #300
# Town & Country Blvd #300 => Town & Country Blvd #300
# Everett Knolls => None
# TX 36 => None
# Highway 36 => None
# Larchmont => None
# Riley Fuzzel => None
